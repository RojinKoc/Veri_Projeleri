# %%
import pandas as pd

df = pd.read_csv("C:\Veri_Projeleri\owid-covid-data.csv")

df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.shape
# Out:
# (350085, 67)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 350085 entries, 0 to 350084
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    350085 non-null  str
#  1   continent                                   333420 non-null  str
#  2   location                                    350085 non-null  str
#  3   date                                        350085 non-null  str
#  4   total_cases                                 312088 non-null  float64
#  5   new_cases                                   340457 non-null  float64
#  6   new_cases_smoothed                          339198 non-null  float64
#  7   total_deaths                                290501 non-null  float64
#  8   new_deaths                                  340511 non-null  float64
#  9   new_deaths_smoothed                         339281 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  3.120880e+05  3.404570e+05        3.391980e+05  2.905010e+05
# mean   6.683354e+06  9.601634e+03        9.637066e+03  8.602180e+04
# std    4.068903e+07  1.102769e+05        9.447784e+04  4.398873e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    8.090000e+03  0.000000e+00        2.860000e-01  1.270000e+02
# 50%    7.020500e+04  2.000000e+00        2.485700e+01  1.328000e+03
# 75%    7.409558e+05  2.640000e+02        4.978570e+02  1.192200e+04
# max    7.714071e+08  8.401961e+06        6.402036e+06  6.972139e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  340511.000000        339281.000000            312088.000000
# mean       85.511055            85.817071            101749.851259
# std       613.687971           559.130004            151265.689121
# min         0.000000             0.000000                 0.000000
# ...

# %%
df.location.unique()
# Out:
# <ArrowStringArray>
# [        'Afghanistan',              'Africa',             'Albania',
#              'Algeria',      'American Samoa',             'Andorra',
#               'Angola',            'Anguilla', 'Antigua and Barbuda',
#            'Argentina',
#  ...
#              'Vatican',           'Venezuela',             'Vietnam',
#                'Wales',   'Wallis and Futuna',      'Western Sahara',
#                'World',               'Yemen',              'Zambia',
#             'Zimbabwe']
# Length: 255, dtype: str

# %%
df_tr = df[df['location'] == 'Turkey']

# %%
df_tr.shape
# Out:
# (1385, 67)

# %%
df_tr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1385 entries, 318401 to 319785
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    1385 non-null   str
#  1   continent                                   1385 non-null   str
#  2   location                                    1385 non-null   str
#  3   date                                        1385 non-null   str
#  4   total_cases                                 1316 non-null   float64
#  5   new_cases                                   1385 non-null   float64
#  6   new_cases_smoothed                          1380 non-null   float64
#  7   total_deaths                                1310 non-null   float64
#  8   new_deaths                                  1385 non-null   float64
#  9   new_deaths_smoothed                         1380 non-null   float64
# ...

# %%
df_tr['date'] = df_tr['date'].to_timestamp

# %%
df_tr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1385 entries, 318401 to 319785
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    1385 non-null   str
#  1   continent                                   1385 non-null   str
#  2   location                                    1385 non-null   str
#  3   date                                        1385 non-null   object
#  4   total_cases                                 1316 non-null   float64
#  5   new_cases                                   1385 non-null   float64
#  6   new_cases_smoothed                          1380 non-null   float64
#  7   total_deaths                                1310 non-null   float64
#  8   new_deaths                                  1385 non-null   float64
#  9   new_deaths_smoothed                         1380 non-null   float64
# ...

# %%
df_tr = df[df['location'] == 'Turkey'].copy()

# %%
df_tr['date'] = pd.to_datetime(df_tr['date'])

# %%
df_tr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1385 entries, 318401 to 319785
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    1385 non-null   str
#  1   continent                                   1385 non-null   str
#  2   location                                    1385 non-null   str
#  3   date                                        1385 non-null   datetime64[us]
#  4   total_cases                                 1316 non-null   float64
#  5   new_cases                                   1385 non-null   float64
#  6   new_cases_smoothed                          1380 non-null   float64
#  7   total_deaths                                1310 non-null   float64
#  8   new_deaths                                  1385 non-null   float64
#  9   new_deaths_smoothed                         1380 non-null   float64
# ...

# %%
df_tr['new_cases'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_tr['new_deaths'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_tr['new_cases'].max()
# Out:
# np.float64(406321.0)

# %%
df_tr[df_tr['new_cases'] == 406321.0]
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 319341      TUR      Asia   Turkey 2022-07-31   16294951.0   406321.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 319341           58045.857       99703.0       336.0                 48.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 319341  ...          41.1                     NaN                        2.81
#
#         life_expectancy  human_development_index  population  \
# 319341            77.69                     0.82  85341248.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 319341                             218456.48                        18.77
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 319341              8.09                                2559.7996
#
# [1 rows x 67 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df_tr['date'], df_tr['new_cases'])
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.show()

# %%
df_tr['new_cases_7day_avg'] = df_tr['new_cases'].rolling(window=7).mean()

# %%
plt.plot(df_tr['date'], df_tr['new_cases_7day_avg'])
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.show()

# %%
df_tr['new_cases'].sum()
# Out:
# np.float64(17004677.0)

# %%
df_tr['new_deaths'].sum()
# Out:
# np.float64(101419.0)

# %%
case_fatality_rate = df_tr['new_deaths'].sum() / df_tr['new_cases'].sum() * 100
case_fatality_rate
# Out:
# np.float64(0.59641826775069)

# %%
df_tr['year'] = df_tr['date'].dt.year

# %%
df_tr.groupby('year')[['new_cases', 'new_deaths']].sum()
# Out:
#       new_cases  new_deaths
# year
# 2020  2194272.0     20642.0
# 2021  7247492.0     61462.0
# 2022  7562913.0     19315.0
# 2023        0.0         0.0

# %%
yillik_ozet = pd.DataFrame(df_tr.groupby('year')[['new_cases', 'new_deaths']].sum())

# %%
yillik_ozet
# Out:
#       new_cases  new_deaths
# year
# 2020  2194272.0     20642.0
# 2021  7247492.0     61462.0
# 2022  7562913.0     19315.0
# 2023        0.0         0.0

# %%
yillik_ozet['olum_orani'] = yillik_ozet['new_deaths'] / yillik_ozet['new_cases'] * 100

# %%
yillik_ozet
# Out:
#       new_cases  new_deaths  olum_orani
# year
# 2020  2194272.0     20642.0    0.940722
# 2021  7247492.0     61462.0    0.848045
# 2022  7562913.0     19315.0    0.255391
# 2023        0.0         0.0         NaN

# %%
yillik_ozet.to_excel('turkiye_covid_ozeti.xlsx')
